# %%
import sys
import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.4.1
# Keras Version: 2.4.0
#
# Python 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# Pandas 1.1.3
# Scikit-Learn 0.23.2
# GPU is NOT AVAILABLE

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import nltk
import re
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, LSTM, Conv1D, MaxPool1D, Bidirectional
from tensorflow.keras.models import Model
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ifyuc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score
import sklearn.metrics as metrics
from sklearn.metrics import plot_confusion_matrix
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle

# %%
df=pd.read_csv('train.csv')
df = shuffle(df)
df = df.reset_index(drop=True)
df.isnull().sum()    
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18285 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      18285 non-null  int64
#  1   title   18285 non-null  object
#  2   author  18285 non-null  object
#  3   text    18285 non-null  object
#  4   label   18285 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 857.1+ KB

# %%
'''conversion_dict = { 0:'Real', 1:'Fake'}
df['label'] = df['label'].replace(conversion_dict)
df.label.value_counts()'''
# Out:
# "conversion_dict = { 0:'Real', 1:'Fake'}\ndf['label'] = df['label'].replace(conversion_dict)\ndf.label.value_counts()"

# %%
df.drop(["title"],axis=1,inplace=True)
df.drop(["id"],axis=1,inplace=True)
df.drop(["author"],axis=1,inplace=True)

df['text']=df['text'].apply(str)
df['text'] = df['text'].apply(lambda x: x.lower())

df = shuffle(df)
df = df.reset_index(drop=True)

# %%
df['text'][0]
# Out:
# 'this is an update of an article that was  published earlier this year. the soaring cost of prescription drugs has generated outrage among politicians and patients. some cancer drugs carry price tags of more than $100, 000 a year, and health plans are increasingly asking people to shoulder a greater share of the cost. the latest outrage involves the price of epipen, a lifesaving injection device for people with severe allergies, which has risen to more than $600 for the list price of a   set, from less than $100 when mylan acquired the product in 2007. a bipartisan group of senators has demanded that mylan explain why the cost of epipen has skyrocketed, and others have called for congressional hearings, like those that examined price increases by turing pharmaceuticals and valeant pharmaceuticals international. in surveys, americans routinely say drug prices are a top health care concern, and it has been an issue on the presidential campaign trail. but there are no simple answers. much of the attention has focused on a handful of pharmaceutical companies that have snapped up old drugs and then aggressively raised prices, sometimes by more than 1, 000 percent. last fall, martin shkreli, the founder and former chief executive of turing pharmaceuticals, ignited a fierce response on social media after it was reported that his company had raised the price of a   drug to treat toxoplasmosis to $750 a tablet from $13. 50. and valeant pharmaceuticals international has received similar attention for raising the price of many of its drugs, including two heart medications, nitropress and isuprel. critics say these companies and others like them have unfairly favored profit over patients’ needs. congress has held several hearings on these tactics, and valeant and turing are under investigation by federal authorities. presidential candidates have singled out these companies on the campaign trail. but even as the drug industry has sought to distance itself from companies it describes as bad actors, insurers, hospitals and other major health care players have raised alarms about the rising cost of new drugs, including those that treat cancer, hepatitis c and rare diseases. some of those drugs can cost $300, 000 a year. higher drug prices threaten to raise insurance premiums and patients’    expenses and can cost taxpayers more because of medicaid and other government programs. but drug companies say the prices reflect the enormous investment of time and resources that go into bringing a drug to market and argue that many times, their drugs can prevent more expensive medical interventions like surgery and hospitalization. the answer to this is more complicated than one might expect. manufacturers set list prices for their   drugs those are the   figures that have sent congress and presidential candidates into fits of outrage. but almost no one actually pays those prices. insurers and   managers, who manage drug plans for insurers, negotiate discounts and rebates, which lowers the effective cost of a drug. and they have been getting better at doing this. that is why, although list prices for drugs rose about 12 percent in 2015, net prices  —   what insurers and employers actually paid  —   grew only about 2. 8 percent, the lowest rate in years, according to ims health, a research firm. insurers and others say that lower figure obscures the larger price increases in specific areas like cancer treatment, where less competition exists and it is more difficult to pit manufacturers against one another. in the case of epipen, mylan has a virtual monopoly after a similar product was withdrawn from the market about a year ago. what’s more, drug makers do profit from raising their list prices because rebates and discounts are often based on a percentage of those prices. “that’s where the real angst in the marketplace is,” said steve miller, chief medical officer of express scripts. a drug’s path from the manufacturer to the patient is circuitous, and m ...

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ifyuc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
#2 and 1 letter words delete and return list
def remove_stopwords(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
            result.append(token)
            
    return result

# %%
df['text'] = df['text'].apply(remove_stopwords)

# %%
df['text'][0]
# Out:
# ['update',
#  'article',
#  'published',
#  'earlier',
#  'year',
#  'soaring',
#  'cost',
#  'prescription',
#  'drugs',
#  'generated',
#  'outrage',
#  'politicians',
#  'patients',
#  'cancer',
#  'drugs',
#  'carry',
#  'price',
#  'tags',
#  'year',
#  'health',
#  'plans',
#  'increasingly',
#  'asking',
#  'people',
#  'shoulder',
#  'greater',
#  'share',
#  'cost',
#  'latest',
#  'outrage',
#  'involves',
#  'price',
#  'epipen',
#  'lifesaving',
#  'injection',
#  'device',
#  'people',
#  'severe',
#  'allergies',
#  'risen',
#  'list',
#  'price',
#  'mylan',
#  'acquired',
#  'product',
#  'bipartisan',
#  'group',
#  'senators',
#  'demanded',
#  'mylan',
#  'explain',
#  'cost',
#  'epipen',
#  'skyrocketed',
#  'called',
#  'congressional',
#  'hearings',
#  'like',
#  'examined',
#  'price',
#  'increases',
#  'turing',
#  'pharmaceuticals',
#  'valeant',
#  'pharmaceuticals',
#  'international',
#  'surveys',
#  'americans',
#  'routinely',
#  'drug',
#  'prices',
#  'health',
#  'care',
#  'concern',
#  'issue',
#  'presidential',
#  'campaign',
#  'trail',
#  'simple',
#  'answers',
#  'attention',
#  'focused',
#  'handful',
#  'pharmaceutical',
#  'companies',
#  'snapped',
#  'drugs',
#  'aggressively',
#  'raised',
#  'prices',
#  'percent',
#  'fall',
#  'martin',
#  'shkreli',
#  'founder',
#  'chief',
#  'executive',
#  'turing',
#  'pharmaceuticals',
#  'ignited',
#  'fierce',
#  'response',
#  'social',
#  'media',
#  'reported',
#  'company',
#  'raised',
#  'price',
#  'drug',
#  'treat',
#  'toxoplasmosis',
#  'tablet',
#  'valeant',
#  'pharmaceuticals',
#  'international',
#  'received',
#  'similar',
#  'attention',
#  'raising',
#  'price',
#  'drugs',
#  'including',
#  'heart',
#  'medications',
#  'nitropress',
#  'isuprel',
#  'critics',
#  'companies',
#  'like',
#  'unfairly',
#  'favored',
#  'profit',
#  'patients',
#  'needs',
#  'congress',
#  'held',
#  'hearings',
#  'tactics',
#  'valeant',
#  'turing',
#  'investigation',
#  'federal',
#  'authorities',
#  'presidential',
#  'candidates',
#  'singled',
#  'companies',
#  'campaign',
#  'trail',
#  'drug',
#  'industry',
#  'sought',
#  'distance',
#  'companies',
#  'describes',
#  'actors',
#  'insurers',
#  'hospitals',
#  'major',
#  'health',
#  'care',
#  'players',
#  'raised',
#  'alarms',
#  'rising',
#  'cost',
#  'drugs',
#  'including',
#  'treat',
#  'cancer',
#  'hepatitis',
#  'rare',
#  'diseases',
#  'drugs',
#  'cost',
#  'year',
#  'higher',
#  'drug',
#  'prices',
#  'threaten',
#  'raise',
#  'insurance',
#  'premiums',
#  'patients',
#  'expenses',
#  'cost',
#  'taxpayers',
#  'medicaid',
#  'government',
#  'programs',
#  'drug',
#  'companies',
#  'prices',
#  'reflect',
#  'enormous',
#  'investment',
#  'time',
#  'resources',
#  'bringing',
#  'drug',
#  'market',
#  'argue',
#  'times',
#  'drugs',
#  'prevent',
#  'expensive',
#  'medical',
#  'interventions',
#  'like',
#  'surgery',
#  'hospitalization',
#  'answer',
#  'complicated',
#  'expect',
#  'manufacturers',
#  'list',
#  'prices',
#  'drugs',
#  'figures',
#  'sent',
#  'congress',
#  'presidential',
#  'candidates',
#  'fits',
#  'outrage',
#  'actually',
#  'pays',
#  'prices',
#  'insurers',
#  'managers',
#  'manage',
#  'drug',
#  'plans',
#  'insurers',
#  'negotiate',
#  'discounts',
#  'rebates',
#  'lowers',
#  'effective',
#  'cost',
#  'drug',
#  'getting',
#  'better',
#  'list',
#  'prices',
#  'drugs',
#  'rose',
#  'percent',
#  'prices',
#  'insurers',
#  'employers',
#  'actually',
#  'paid',
#  'grew',
#  'percent',
#  'lowest',
#  'rate',
#  'years',
#  'according',
#  'health',
#  'research',
#  'firm',
#  'insurers',
#  'lower',
#  'figure',
#  'obscures',
#  'larger',
#  'price',
#  'increases',
#  'specific',
#  'areas',
#  'like',
#  'cancer',
#  'treatment',
#  'competition',
#  'exists',
#  'difficult',
#  'manufacturers',
#  'case',
#  'epipen',
#  'mylan',
#  'virtual',
#  'monopoly',
#  'similar',
#  'product',
#  'withdrawn',
#  'market',
#  'year',
#  'drug',
#  'makers',
#  'profit',
#  'raising',
#  'list',
#  'prices',
#  'rebates',
#  'discounts',
#  'based',
#  'percentage',
#  'prices',
#  'real',
#  'angst',
#  'marketplace',
#  'said',
#  'steve',
#  'miller',
#  'chief',
#  'medical',
#  'officer',
#  'express',
#  'scripts',
#  'drug',
#  'path',
#  'manufacturer',
#  'patient',
#  'circuitous',
#  'middlemen',
#  'paid',
#  'pharmaceutical',
#  'company',
#  'sends',
#  'drug',
#  'distributor',
#  'takes',
#  'sells',
#  'drug',
#  'pharmacy',
#  'pockets',
#  'dispensing',
#  'medication',
#  'patient',
#  'patient',
#  'insured',
#  'manager',
#  'paid',
#  'processing',
#  'transaction',
#  'pharmacy',
#  'insurer',
#  'employer',
#  'manager',
#  'handles',
#  'rebates',
#  'flow',
#  'drug',
#  'maker',
#  'insurer',
#  'employer',
#  'makes',
#  'issue',
#  'frustrating',
#  'visiting',
#  'pharmacy',
#  'pick',
#  'prescription',
#  'simple',
#  'retail',
#  'pharmacy',
#  'looks',
#  'like',
#  'retail',
#  'transaction',
#  'said',
#  'adam',
#  'fein',
#  'president',
#  'pembroke',
#  'consulting',
#  'management',
#  'advisory',
#  'business',
#  'research',
#  'company',
#  'like',
#  'buying',
#  'bottle',
#  'orange',
#  'juice',
#  'patients',
#  'choose',
#  'drug',
#  'picking',
#  'paying',
#  'said',
#  'crazy',
#  'good',
#  'news',
#  'vast',
#  'majority',
#  'drugs',
#  'dispensed',
#  'united',
#  'states',
#  'percent',
#  'generics',
#  'alternatives',
#  'drugs',
#  'doctor',
#  'writes',
#  'prescription',
#  'good',
#  'chance',
#  'cost',
#  'illness',
#  'require',
#  'newer',
#  'drug',
#  'insurers',
#  'requiring',
#  'increasingly',
#  'large',
#  'share',
#  'drug',
#  'cost',
#  'people',
#  'covered',
#  'health',
#  'plans',
#  'large',
#  'deductibles',
#  'require',
#  'price',
#  'drugs',
#  'limit',
#  'thousands',
#  'dollars',
#  'year',
#  'plans',
#  'requiring',
#  'patients',
#  'need',
#  'expensive',
#  'specialty',
#  'drugs',
#  'contribute',
#  'percentage',
#  'list',
#  'price',
#  'drug',
#  'companies',
#  'help',
#  'cover',
#  'patients',
#  'costs',
#  'assistance',
#  'programs',
#  'patients',
#  'sickest',
#  'require',
#  'expensive',
#  'drugs',
#  'vulnerable',
#  'soaring',
#  'drug',
#  'prices',
#  'sort',
#  'embedded',
#  'health',
#  'care',
#  'price',
#  'price',
#  'customer',
#  'fein',
#  'said',
#  'case',
#  'soak',
#  'poor']

# %%
df
# Out:
#                                                     text  label
# 0      [update, article, published, earlier, year, so...      0
# 1      [posted, patriotrising, comments, phds, unable...      1
# 2      [david, duke, mark, collett, discuss, duke, se...      1
# 3      [ratings, annual, academy, awards, slid, secon...      0
# 4      [moonlight, barry, jenkins, celebrated, intima...      0
# ...                                                  ...    ...
# 18280  [proof, hillary, clinton, foundation, working,...      1
# 18281  [istanbul, turkey, said, wednesday, prisons, t...      0
# 18282  [amazing, video, hispanics, trump, miami, stor...      1
# 18283  [like, companies, confronted, sexual, harassme...      0
# 18284  [aviv, president, donald, trump, seriously, co...      0
#
# [18285 rows x 2 columns]

# %%
list_of_words = []
for i in df.text:
    for j in i:
        list_of_words.append(j)

# %%
len(list_of_words)
# Out:
# 6776215

# %%
total_words = len(list(set(list_of_words)))
total_words #unique words
# Out:
# 149278

# %%
df['text_of_use'] = df['text'].apply(lambda x: " ".join(x))

# %%
df['text_of_use'][0]
# Out:
# 'update article published earlier year soaring cost prescription drugs generated outrage politicians patients cancer drugs carry price tags year health plans increasingly asking people shoulder greater share cost latest outrage involves price epipen lifesaving injection device people severe allergies risen list price mylan acquired product bipartisan group senators demanded mylan explain cost epipen skyrocketed called congressional hearings like examined price increases turing pharmaceuticals valeant pharmaceuticals international surveys americans routinely drug prices health care concern issue presidential campaign trail simple answers attention focused handful pharmaceutical companies snapped drugs aggressively raised prices percent fall martin shkreli founder chief executive turing pharmaceuticals ignited fierce response social media reported company raised price drug treat toxoplasmosis tablet valeant pharmaceuticals international received similar attention raising price drugs including heart medications nitropress isuprel critics companies like unfairly favored profit patients needs congress held hearings tactics valeant turing investigation federal authorities presidential candidates singled companies campaign trail drug industry sought distance companies describes actors insurers hospitals major health care players raised alarms rising cost drugs including treat cancer hepatitis rare diseases drugs cost year higher drug prices threaten raise insurance premiums patients expenses cost taxpayers medicaid government programs drug companies prices reflect enormous investment time resources bringing drug market argue times drugs prevent expensive medical interventions like surgery hospitalization answer complicated expect manufacturers list prices drugs figures sent congress presidential candidates fits outrage actually pays prices insurers managers manage drug plans insurers negotiate discounts rebates lowers effective cost drug getting better list prices drugs rose percent prices insurers employers actually paid grew percent lowest rate years according health research firm insurers lower figure obscures larger price increases specific areas like cancer treatment competition exists difficult manufacturers case epipen mylan virtual monopoly similar product withdrawn market year drug makers profit raising list prices rebates discounts based percentage prices real angst marketplace said steve miller chief medical officer express scripts drug path manufacturer patient circuitous middlemen paid pharmaceutical company sends drug distributor takes sells drug pharmacy pockets dispensing medication patient patient insured manager paid processing transaction pharmacy insurer employer manager handles rebates flow drug maker insurer employer makes issue frustrating visiting pharmacy pick prescription simple retail pharmacy looks like retail transaction said adam fein president pembroke consulting management advisory business research company like buying bottle orange juice patients choose drug picking paying said crazy good news vast majority drugs dispensed united states percent generics alternatives drugs doctor writes prescription good chance cost illness require newer drug insurers requiring increasingly large share drug cost people covered health plans large deductibles require price drugs limit thousands dollars year plans requiring patients need expensive specialty drugs contribute percentage list price drug companies help cover patients costs assistance programs patients sickest require expensive drugs vulnerable soaring drug prices sort embedded health care price price customer fein said case soak poor'

# %%
df['text'][0]
# Out:
# ['update',
#  'article',
#  'published',
#  'earlier',
#  'year',
#  'soaring',
#  'cost',
#  'prescription',
#  'drugs',
#  'generated',
#  'outrage',
#  'politicians',
#  'patients',
#  'cancer',
#  'drugs',
#  'carry',
#  'price',
#  'tags',
#  'year',
#  'health',
#  'plans',
#  'increasingly',
#  'asking',
#  'people',
#  'shoulder',
#  'greater',
#  'share',
#  'cost',
#  'latest',
#  'outrage',
#  'involves',
#  'price',
#  'epipen',
#  'lifesaving',
#  'injection',
#  'device',
#  'people',
#  'severe',
#  'allergies',
#  'risen',
#  'list',
#  'price',
#  'mylan',
#  'acquired',
#  'product',
#  'bipartisan',
#  'group',
#  'senators',
#  'demanded',
#  'mylan',
#  'explain',
#  'cost',
#  'epipen',
#  'skyrocketed',
#  'called',
#  'congressional',
#  'hearings',
#  'like',
#  'examined',
#  'price',
#  'increases',
#  'turing',
#  'pharmaceuticals',
#  'valeant',
#  'pharmaceuticals',
#  'international',
#  'surveys',
#  'americans',
#  'routinely',
#  'drug',
#  'prices',
#  'health',
#  'care',
#  'concern',
#  'issue',
#  'presidential',
#  'campaign',
#  'trail',
#  'simple',
#  'answers',
#  'attention',
#  'focused',
#  'handful',
#  'pharmaceutical',
#  'companies',
#  'snapped',
#  'drugs',
#  'aggressively',
#  'raised',
#  'prices',
#  'percent',
#  'fall',
#  'martin',
#  'shkreli',
#  'founder',
#  'chief',
#  'executive',
#  'turing',
#  'pharmaceuticals',
#  'ignited',
#  'fierce',
#  'response',
#  'social',
#  'media',
#  'reported',
#  'company',
#  'raised',
#  'price',
#  'drug',
#  'treat',
#  'toxoplasmosis',
#  'tablet',
#  'valeant',
#  'pharmaceuticals',
#  'international',
#  'received',
#  'similar',
#  'attention',
#  'raising',
#  'price',
#  'drugs',
#  'including',
#  'heart',
#  'medications',
#  'nitropress',
#  'isuprel',
#  'critics',
#  'companies',
#  'like',
#  'unfairly',
#  'favored',
#  'profit',
#  'patients',
#  'needs',
#  'congress',
#  'held',
#  'hearings',
#  'tactics',
#  'valeant',
#  'turing',
#  'investigation',
#  'federal',
#  'authorities',
#  'presidential',
#  'candidates',
#  'singled',
#  'companies',
#  'campaign',
#  'trail',
#  'drug',
#  'industry',
#  'sought',
#  'distance',
#  'companies',
#  'describes',
#  'actors',
#  'insurers',
#  'hospitals',
#  'major',
#  'health',
#  'care',
#  'players',
#  'raised',
#  'alarms',
#  'rising',
#  'cost',
#  'drugs',
#  'including',
#  'treat',
#  'cancer',
#  'hepatitis',
#  'rare',
#  'diseases',
#  'drugs',
#  'cost',
#  'year',
#  'higher',
#  'drug',
#  'prices',
#  'threaten',
#  'raise',
#  'insurance',
#  'premiums',
#  'patients',
#  'expenses',
#  'cost',
#  'taxpayers',
#  'medicaid',
#  'government',
#  'programs',
#  'drug',
#  'companies',
#  'prices',
#  'reflect',
#  'enormous',
#  'investment',
#  'time',
#  'resources',
#  'bringing',
#  'drug',
#  'market',
#  'argue',
#  'times',
#  'drugs',
#  'prevent',
#  'expensive',
#  'medical',
#  'interventions',
#  'like',
#  'surgery',
#  'hospitalization',
#  'answer',
#  'complicated',
#  'expect',
#  'manufacturers',
#  'list',
#  'prices',
#  'drugs',
#  'figures',
#  'sent',
#  'congress',
#  'presidential',
#  'candidates',
#  'fits',
#  'outrage',
#  'actually',
#  'pays',
#  'prices',
#  'insurers',
#  'managers',
#  'manage',
#  'drug',
#  'plans',
#  'insurers',
#  'negotiate',
#  'discounts',
#  'rebates',
#  'lowers',
#  'effective',
#  'cost',
#  'drug',
#  'getting',
#  'better',
#  'list',
#  'prices',
#  'drugs',
#  'rose',
#  'percent',
#  'prices',
#  'insurers',
#  'employers',
#  'actually',
#  'paid',
#  'grew',
#  'percent',
#  'lowest',
#  'rate',
#  'years',
#  'according',
#  'health',
#  'research',
#  'firm',
#  'insurers',
#  'lower',
#  'figure',
#  'obscures',
#  'larger',
#  'price',
#  'increases',
#  'specific',
#  'areas',
#  'like',
#  'cancer',
#  'treatment',
#  'competition',
#  'exists',
#  'difficult',
#  'manufacturers',
#  'case',
#  'epipen',
#  'mylan',
#  'virtual',
#  'monopoly',
#  'similar',
#  'product',
#  'withdrawn',
#  'market',
#  'year',
#  'drug',
#  'makers',
#  'profit',
#  'raising',
#  'list',
#  'prices',
#  'rebates',
#  'discounts',
#  'based',
#  'percentage',
#  'prices',
#  'real',
#  'angst',
#  'marketplace',
#  'said',
#  'steve',
#  'miller',
#  'chief',
#  'medical',
#  'officer',
#  'express',
#  'scripts',
#  'drug',
#  'path',
#  'manufacturer',
#  'patient',
#  'circuitous',
#  'middlemen',
#  'paid',
#  'pharmaceutical',
#  'company',
#  'sends',
#  'drug',
#  'distributor',
#  'takes',
#  'sells',
#  'drug',
#  'pharmacy',
#  'pockets',
#  'dispensing',
#  'medication',
#  'patient',
#  'patient',
#  'insured',
#  'manager',
#  'paid',
#  'processing',
#  'transaction',
#  'pharmacy',
#  'insurer',
#  'employer',
#  'manager',
#  'handles',
#  'rebates',
#  'flow',
#  'drug',
#  'maker',
#  'insurer',
#  'employer',
#  'makes',
#  'issue',
#  'frustrating',
#  'visiting',
#  'pharmacy',
#  'pick',
#  'prescription',
#  'simple',
#  'retail',
#  'pharmacy',
#  'looks',
#  'like',
#  'retail',
#  'transaction',
#  'said',
#  'adam',
#  'fein',
#  'president',
#  'pembroke',
#  'consulting',
#  'management',
#  'advisory',
#  'business',
#  'research',
#  'company',
#  'like',
#  'buying',
#  'bottle',
#  'orange',
#  'juice',
#  'patients',
#  'choose',
#  'drug',
#  'picking',
#  'paying',
#  'said',
#  'crazy',
#  'good',
#  'news',
#  'vast',
#  'majority',
#  'drugs',
#  'dispensed',
#  'united',
#  'states',
#  'percent',
#  'generics',
#  'alternatives',
#  'drugs',
#  'doctor',
#  'writes',
#  'prescription',
#  'good',
#  'chance',
#  'cost',
#  'illness',
#  'require',
#  'newer',
#  'drug',
#  'insurers',
#  'requiring',
#  'increasingly',
#  'large',
#  'share',
#  'drug',
#  'cost',
#  'people',
#  'covered',
#  'health',
#  'plans',
#  'large',
#  'deductibles',
#  'require',
#  'price',
#  'drugs',
#  'limit',
#  'thousands',
#  'dollars',
#  'year',
#  'plans',
#  'requiring',
#  'patients',
#  'need',
#  'expensive',
#  'specialty',
#  'drugs',
#  'contribute',
#  'percentage',
#  'list',
#  'price',
#  'drug',
#  'companies',
#  'help',
#  'cover',
#  'patients',
#  'costs',
#  'assistance',
#  'programs',
#  'patients',
#  'sickest',
#  'require',
#  'expensive',
#  'drugs',
#  'vulnerable',
#  'soaring',
#  'drug',
#  'prices',
#  'sort',
#  'embedded',
#  'health',
#  'care',
#  'price',
#  'price',
#  'customer',
#  'fein',
#  'said',
#  'case',
#  'soak',
#  'poor']

# %%
df
# Out:
#                                                     text  label  \
# 0      [update, article, published, earlier, year, so...      0
# 1      [posted, patriotrising, comments, phds, unable...      1
# 2      [david, duke, mark, collett, discuss, duke, se...      1
# 3      [ratings, annual, academy, awards, slid, secon...      0
# 4      [moonlight, barry, jenkins, celebrated, intima...      0
# ...                                                  ...    ...
# 18280  [proof, hillary, clinton, foundation, working,...      1
# 18281  [istanbul, turkey, said, wednesday, prisons, t...      0
# 18282  [amazing, video, hispanics, trump, miami, stor...      1
# 18283  [like, companies, confronted, sexual, harassme...      0
# 18284  [aviv, president, donald, trump, seriously, co...      0
#
#                                              text_of_use
# 0      update article published earlier year soaring ...
# 1      posted patriotrising comments phds unable alte...
# 2      david duke mark collett discuss duke senate ra...
# 3      ratings annual academy awards slid second cons...
# 4      moonlight barry jenkins celebrated intimate po...
# ...                                                  ...
# 18280  proof hillary clinton foundation working russi...
# 18281  istanbul turkey said wednesday prisons tens th...
# 18282  amazing video hispanics trump miami storm poll...
# 18283  like companies confronted sexual harassment ex...
# 18284  aviv president donald trump seriously consider...
#
# [18285 rows x 3 columns]

# %%
maxlen = -1
for doc in df.text_of_use:
    tokens = nltk.word_tokenize(doc)
    if(maxlen<len(tokens)):
        maxlen = len(tokens)
print("text of use da en cok kelimeye sahip single row su kadar kelimeye sahip", maxlen) #word embeding icin
# Out:
# text of use da en cok kelimeye sahip single row su kadar kelimeye sahip 13682

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.text_of_use, df.label, test_size = 0.2)

# %%
from nltk import word_tokenize

# %%
tokenizer = Tokenizer(num_words = total_words) #tokenizer create to token unique words
tokenizer.fit_on_texts(x_train)
train_sequences = tokenizer.texts_to_sequences(x_train)
test_sequences = tokenizer.texts_to_sequences(x_test)

# %%
df.text_of_use[10]
# Out:
# 'alexa person friday october president obama issued executive order space weather events earth magnetic shields collapsed energetic streams energy flowing earth solar winds completely changed direction events corresponded severe geomagnetic storm tracked satellite video massive plasma wave literally washed planet wave consisted high frequency energy bearing ascension codes codes arrived form light known photons ascended twin flame taught great deal photon packets understand amplituhedrons satellite imagery executive order space weather event took place seen dramatic rise number unexpected effects stillness usual gaia allowing experience pause given chance integrate energy bombarding density time vanished urgency disappeared getting anxiety associated completion tasks nonexistent profound sense peace conscious contact higher dimensional selves body temperatures rising unpredictably dramatically rest powerful light energy intermittently discharging skin spine causing intense tingling sensations increased focus unconsciously shielding mind body soul increased contact higher self appetite fluctuations paired conscious eating fatigue increased sensitivity clairvoyant abilities onset effects earlier week cancelled appointments managed pressing knowing important energy chose isolate intention integration noticed stillness desired energy pushing guides external energies hibernating stillness presence normally review journal entries written specifically guided share entries following writings took place plasma wave moved planet passages excerpts taken directly journals sake authenticity kept copy tact altered prayer assistance person finds guidance share consider efforts success journal entry entered deep meditation experienced intense connection amplituhedon elementals cardinal directions gathered assisted moving amplituhedron energy outward direction degrees moved away earth core multiple crystalline amplituhedrons swirled away center tremendous speeds moved felt rush connection working amplituhedrons different time instead moving individual layer earth connected intensely instantaneously energy moving upward christos grid magdalen grid turn attention outward reconnect radiant pink light great central epiphany felt consciousness proclaim fine need service positioned exactly decided longer yearn earth leave higher familiar realms know right moment waited waited harvest mind continually wanders past multiverses consider gazes honeycomb mazes life wonders concept grander goes guess atom building divine matrix shortly entry moment amplituhedron directly related planet journal entry connected gaia wondered needed visualize amplituhedrons suddenly began moving energy upwards center earth amplituhedron called elementals cardinal directions assistance dramatic moved incredibly fast faster times surface joined mankind different took place standing hands cupped open manifesting amplituhedron revolved spinning heart chakra human remained revolving holding pattern waiting accepted asked consciously step frequencies coming planet accepted free watched marveled beauty geometry floating abstract representation people amplituhedron rose blue lowered brilliant blue water turned degrees right lodged earth second amplituhedron revealed remaining upright hovered buried beneath water soil identical amplituhedrons remained buried right angle earth second levitating realm completely unhindered confused asked higher self scene meant received brief lengthy works explanation density phase earth timelines wobbly splicing asked choose path people bury gravity earth illusion transcend order perfection judgment paths ultimately lead place source paths merely shorter time come frequencies evaluated order little time reevaluate alternate paths difficulty lies trajectory assimilating lessons unity consciousness holding space higher self immediately experiencing double amplituhedrons thought exercise long cells solitude spoke cells brought light cells activating junk ...

# %%
train_sequences[10] #encoding for df.text_of_use[0] ->>> bi sorun var
# Out:
# [13670,
#  38,
#  60038,
#  1837,
#  100,
#  19582,
#  6692,
#  683,
#  146,
#  2461,
#  69,
#  978,
#  3916,
#  4393,
#  1828,
#  7347,
#  3100,
#  3284,
#  2461,
#  34665,
#  2461,
#  1854,
#  3276,
#  198,
#  2461,
#  8877,
#  3594,
#  260,
#  3101,
#  80,
#  1740,
#  603,
#  14,
#  6692,
#  77694,
#  544,
#  77695,
#  337,
#  2336,
#  260,
#  850,
#  5637,
#  32513,
#  202,
#  13,
#  305,
#  9926,
#  750,
#  115,
#  1791,
#  12712,
#  268,
#  531,
#  11063,
#  1929,
#  12,
#  1009,
#  260,
#  2103,
#  976,
#  398,
#  11182,
#  1651,
#  15411,
#  1397,
#  14825,
#  947,
#  1225,
#  31,
#  4080,
#  14825,
#  6692,
#  61,
#  185,
#  146,
#  18577,
#  4919,
#  855,
#  14825,
#  1410,
#  35,
#  111,
#  2089,
#  13,
#  591,
#  14,
#  466,
#  191,
#  1357,
#  1213]

# %%
padded_train = pad_sequences(train_sequences,maxlen = 40, padding = 'post', truncating = 'post')
padded_test = pad_sequences(test_sequences,maxlen = 40, truncating = 'post')

# %%
'''for i,doc in enumerate(padded_train[:2]):
     print("The padded encoding for document",i+1," is : ",doc)'''
padded_train[0] #padded single text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2c6c19d1cc2f> in <module>
#       1 '''for i,doc in enumerate(padded_train[:2]):
#       2      print("The padded encoding for document",i+1," is : ",doc)'''
# ----> 3 padded_test[0] #padded single text
#
# NameError: name 'padded_test' is not defined

# %%
# Sequential Model
model = Sequential()

# Embeddidng layer
model.add(Embedding(total_words, output_dim = 128))


# Bi-Directional RNN and LSTM
model.add(Bidirectional(LSTM(128)))

# Dense layers
model.add(Dense(128, activation = 'relu'))
model.add(Dense(1,activation= 'sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 128)         19107584
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               263168
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 19,403,777
# Trainable params: 19,403,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train = np.asarray(y_train)

# %%
model.fit(padded_train, y_train, batch_size = 64, validation_split = 0.1, epochs = 5)
# Out:
# Epoch 1/5
# 206/206 [==============================] - 61s 279ms/step - loss: 0.4132 - acc: 0.7906 - val_loss: 0.1846 - val_acc: 0.9214
# Epoch 2/5
# 206/206 [==============================] - 57s 275ms/step - loss: 0.0602 - acc: 0.9797 - val_loss: 0.2028 - val_acc: 0.9214
# Epoch 3/5
# 206/206 [==============================] - 57s 277ms/step - loss: 0.0157 - acc: 0.9963 - val_loss: 0.3292 - val_acc: 0.9111
# Epoch 4/5
# 206/206 [==============================] - 56s 274ms/step - loss: 0.0041 - acc: 0.9985 - val_loss: 0.3051 - val_acc: 0.9200
# Epoch 5/5
# 206/206 [==============================] - 56s 272ms/step - loss: 0.0063 - acc: 0.9984 - val_loss: 0.4983 - val_acc: 0.9139

# %%
pred = model.predict(padded_test)

# %%
prediction = []
for i in range(len(pred)):
    if pred[i].item() > 0.95:
        prediction.append(1)
    else:
        prediction.append(0)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(list(y_test), prediction)

print("Model Accuracy : ", accuracy)
# Out:
# Model Accuracy :  0.9012852064533771

# %%
confusion_matrix(y_test,prediction, labels=[0,1]) #1608 true tested text which 63 times ML was wrong
# Out:
# array([[1946,  143],
#        [ 218, 1350]], dtype=int64)

# %%
import os.path
if os.path.isfile('models/lstm_model.h5') is False:
    model.save('models/lstm_model.h5')
